# %% [markdown]
# ## Decision Tree Regression

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
# Load the datasets as frame

df=load_diabetes(as_frame=True).frame

# %%
df.head()
df.shape
# Out:
# (442, 11)

# %%
X = df.drop("target",axis=1)
y=df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3,random_state=42
)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("MSE train:", mean_squared_error(y_train, y_pred_train))
print("MSE test :", mean_squared_error(y_test, y_pred_test))

print("R² train :", r2_score(y_train, y_pred_train))
print("R² test  :", r2_score(y_test, y_pred_test))
# Out:
# MSE train: 0.0
# MSE test : 5419.849624060151
# R² train : 1.0
# R² test  : -0.003990484263665994

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(18,10))
plot_tree(
    model,
    feature_names = X.columns,
    filled = True
)
plt.tight_layout()

# %% [markdown]
# ## Decision Tree using Pre-prunning

# %%
model = DecisionTreeRegressor(max_depth=4,min_samples_leaf=20)
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_leaf=20)

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("MSE train:", mean_squared_error(y_train, y_pred_train))
print("MSE test :", mean_squared_error(y_test, y_pred_test))

print("R² train :", r2_score(y_train, y_pred_train))
print("R² test  :", r2_score(y_test, y_pred_test))
# Out:
# MSE train: 2838.1417153349753
# MSE test : 3088.4126494197785
# R² train : 0.538384577844953
# R² test  : 0.42789244599481113

# %%
plt.figure(figsize=(18,10))
plot_tree(
    model,
    feature_names = X.columns,
    filled = True
)
plt.tight_layout()
