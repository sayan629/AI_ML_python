# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("shop_smart_ecommerce.csv")

# %%
df.head()
df.describe()
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  bool
#  17  Revenue                  12330 non-null  bool
# dtypes: bool(2), float64(7), int64(7), object(2)
# memory usage: 1.5+ MB

# %%
target = df['Revenue'].value_counts()
sns.countplot(
    x='Revenue',
    data = df
)
plt.show()

# %% [markdown]
# ### Feature Processing

# %%
# Convert Boolean Columns in int type

df["Weekend"] = df["Weekend"].astype(int)
df["Revenue"] = df["Revenue"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  int64
#  17  Revenue                  12330 non-null  int64
# dtypes: float64(7), int64(9), object(2)
# memory usage: 1.7+ MB

# %%
# Encode Categorical Variables

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["VisitorType"] = le.fit_transform(df["VisitorType"])
df["Month"] = le.fit_transform(df["Month"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  int64
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  int64
#  16  Weekend                  12330 non-null  int64
#  17  Revenue                  12330 non-null  int64
# dtypes: float64(7), int64(11)
# memory usage: 1.7 MB

# %% [markdown]
# ### Train-Test-Split

# %%
X= df.drop('Revenue',axis=1)
y = df['Revenue']

# %%
X_train,X_test, y_train,y_test = train_test_split(
    X,y,test_size=0.3,random_state=42, stratify=y
)

# stratify=y keeps class proportions balanced.

# %%
X_train.head()
# Out:
#       Administrative  Administrative_Duration  Informational  \
# 7460               4                    45.40              0
# 4687               1                    40.25              0
# 790                0                     0.00              0
# 9057               6                    62.75              0
# 225                0                     0.00              0
#
#       Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 7460                     0.0              14               339.000000
# 4687                     0.0              19               501.766667
# 790                      0.0              13               244.166667
# 9057                     0.0              46              1098.524802
# 225                      0.0               2                19.000000
#
#       BounceRates  ExitRates  PageValues  SpecialDay  Month  OperatingSystems  \
# 7460     0.000000   0.010526         0.0         0.0      3                 2
# 4687     0.000000   0.010526         0.0         0.0      6                 2
# 790      0.000000   0.030769         0.0         0.0      5                 2
# 9057     0.007083   0.016530         0.0         0.0      7                 1
# 225      0.000000   0.100000         0.0         0.0      5                 2
#
#       Browser  Region  TrafficType  VisitorType  Weekend
# 7460        2       1            5            0        0
# 4687        2       1            4            2        0
# 790         5       3            3            2        0
# 9057        1       4            8            2        0
# 225         2       3           11            2        1

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Evaluation
from sklearn.metrics import accuracy_score,f1_score

y_pred = model.predict(X_test) #Prediction

print("Accuracy Score:" ,accuracy_score(y_test,y_pred))
print("f1 Score:" ,f1_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.8499594484995945
# f1 Score: 0.5169712793733682

# %%
# Plot Tree

from sklearn.tree import plot_tree
plt.figure(figsize=(18,10))
plot_tree(
    model,
    feature_names = X.columns,
    class_names = ['No Purchase', 'Purchase'], # 0 =>No Purchase, 1 =>Purchase
    filled = True,
    max_depth=2
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Decision Tree with Post-prunning

# %%
full_tree = DecisionTreeClassifier(random_state=42)
full_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Find Best Alpha
path = full_tree.cost_complexity_pruning_path(X_train,y_train)
ccp_alphas = path.ccp_alph
#  2.32478192e-04 2.33096189e-04 2.33161355e-04 2.33214758e-04
#  2.34433400e-04 2.35618117e-04 2.36228582e-04 2.38303421e-04
#  2.38826961e-04 2.41377979e-04 2.43309002e-04 2.43750379e-04
#  2.43989915e-04 2.45812450e-04 2.53141412e-04 2.55753378e-04
#  2.55879297e-04 2.57469844e-04 2.59347925e-04 2.60688217e-04
#  2.61926053e-04 2.62619241e-04 2.67372530e-04 2.68136452e-04
#  2.69641146e-04 2.73717751e-04 2.75258669e-04 2.77215117e-04
#  2.79568470e-04 2.83860503e-04 2.84256199e-04 2.88374836e-04
#  2.89653574e-04 2.89653574e-04 2.89898467e-04 2.89904357e-04
#  2.94920003e-04 2.99601273e-04 3.03777634e-04 3.04245401e-04
#  3.04770732e-04 3.08963813e-04 3.08963813e-04 3.10882843e-04
#  3.10975296e-04 3.12825860e-04 3.12825860e-04 3.13316725e-04
#  3.14113740e-04 3.15792165e-04 3.20347614e-04 3.23405924e-04
#  3.31855910e-04 3.35170565e-04 3.36151771e-04 3.40028109e-04
#  3.40888219e-04 3.42905365e-04 3.46629387e-04 3.47584289e-04
#  3.50058713e-04 3.57885779e-04 3.62066968e-04 3.64091729e-04
#  3.75453922e-04 3.79182861e-04 3.86204766e-04 3.89328456e-04
#  3.91032325e-04 3.94064280e-04 3.97723859e-04 3.98007428e-04
#  4.00541155e-04 4.28078542e-04 4.28487203e-04 4.30310469e-04
#  4.75605839e-04 4.78088974e-04 4.84304676e-04 5.09411659e-04
#  5.49752576e-04 5.51140738e-04 5.85297197e-04 6.13259216e-04
#  6.97905244e-04 7.24926151e-04 8.14570273e-04 8.38202487e-04
#  1.11066065e-03 1.15956442e-03 1.39185246e-03 1.51626104e-03
#  1.77477299e-03 2.12192667e-03 2.14176815e-03 3.88322376e-03
#  9.54055360e-03 9.95573071e-02]

# %%
# Train our model for all alphas
trees = []
for alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=42, ccp_alpha = alpha)
    model.fit(X_train,y_train)
    f1 = f1_score(y_test, y_pred)
    trees.append((model,alpha,f1))

# %%
best_f1 =0
best_alpha =0

for model, alpha,f1 in trees:   
    if f1>best_f1:
        best_f1 = f1
        best_alpha = alpha

print("Best Alpha:", best_alpha)
print("Best F1 Score:", best_f1)
# Out:
# Best Alpha: 0.0
# Best F1 Score: 0.5169712793733682

# %%
best_model = DecisionTreeClassifier(ccp_alpha=best_alpha)
best_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=np.float64(0.0))

# %%
plt.figure(figsize=(18,10))
plot_tree(
    best_model,
    feature_names = X.columns,
    class_names = ['No Purchase', 'Purchase'],
    filled = True
)
plt.title(f"Pruned Decision Tree (ccp_alpha={best_alpha:.6f})")
plt.tight_layout()
plt.show()

# %%
print(best_model.score(X_test,y_test))
# Out:
# 0.8513111651797783
