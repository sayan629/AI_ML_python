# %%
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
print("First 10 rows of Dataset:")
print(df.drop(columns=["petal_ratio"], errors="ignore").head(10))

print("\nShape of Dataset:")
print(df.shape)

print("\nDataTypes of Each Column:")
print(df.dtypes)

print("\nSummary Statistics of Dataset:")
print(df.describe())

print("\n----- FILTERED DATA (petal_length > 4.5 AND species = Iris-virginica) -----\n")
filtered= df[(df["petal_length"]>4.5) & (df["species"]=="Iris-virginica")]
print(filtered.drop(columns=["petal_ratio"], errors="ignore"))

print("\n----- GROUP BY SPECIES STATISTICS -----\n")
grouped=df.groupby("species").agg({
    "sepal_length":"mean",
    "petal_width":"max",
    "sepal_width":"std"
})
print(grouped)
print("\n")



df["petal_ratio"] = df["petal_length"] / df["petal_width"]
print("\n----- AVERAGE PETAL RATIO FOR EACH SPECIES -----")
avg_ratio = df.groupby("species")["petal_ratio"].mean()
print(avg_ratio)
# Out:
# First 10 rows of Dataset:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#
# Shape of Dataset:
# (150, 5)
#
# DataTypes of Each Column:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# ...
